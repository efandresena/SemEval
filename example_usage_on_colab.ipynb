# %% [markdown]
# <a href="https://colab.research.google.com/github/efandresena/SemEval/blob/main/example_usage_on_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import necessary

# %%
import os
import pandas as pd
import torch
import torch.nn as nn
import numpy as np
import random
from torch.utils.data import Dataset
from transformers import (
    AutoTokenizer, AutoModelForSequenceClassification,
    Trainer, TrainingArguments, DataCollatorWithPadding,
    EarlyStoppingCallback
)
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
import warnings
warnings.filterwarnings('ignore')

# %%
from huggingface_hub import HfApi, Repository
from huggingface_hub import upload_folder

# %%
# !git clone https://github.com/efandresena/SemEval.git
# Out:
# Cloning into 'SemEval'...
# remote: Enumerating objects: 202, done.
# remote: Counting objects: 100% (202/202), done.
# remote: Compressing objects: 100% (113/113), done.
# remote: Total 202 (delta 110), reused 154 (delta 86), pack-reused 0 (from 0)
# Receiving objects: 100% (202/202), 7.16 MiB | 5.29 MiB/s, done.
# Resolving deltas: 100% (110/110), done.

# %%
# !cd SemEval/

# %%
from SemEval.utils import load_model, predict

# %%
# Example usage for subtask 1
HF_MODEL_NAME = "mirindraf/aims-sentiment-analysis"  # Change as needed
lan = "eng"  # Change as needed

tokenizer, model = load_model(HF_MODEL_NAME, lan)

dev_path = "/content/SemEval/dev_phase/subtask1/dev/eng.csv"  # Path to your dev set CSV
dev_pd = pd.read_csv(dev_path)
if __name__ == "__main__":
    output_csv = predict(tokenizer, model, dev_pd)
    print(f"Predictions saved to {output_csv}")
